# %% [markdown]
# #### The Scenario: You are building an internal tool for an HR team. They are tired of manually comparing resumes to job descriptions. They want an AI that reads a Candidate's Resume (PDF) and a Live Job Posting (URL), and instantly generates a report on why the candidate fits or fails.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from uuid import uuid4

import time
from docx import Document

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pinecone import Pinecone, ServerlessSpec
from langchain_groq import ChatGroq
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough


from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
#load split

loader = PyPDFLoader("./files/resume.pdf")
docs = loader.load()
docs

# webloader

job_url = "https://job-boards.greenhouse.io/greenhouse/jobs/7477093"
loader = WebBaseLoader(job_url)
job_docs = loader.load()

all_docs = docs + job_docs

# Split
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 200
)
chunks = splitter.split_documents(all_docs)
chunks
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='SAHIL AMUNDKAR \nAI/ML Engineer \nTempe, AZ | 5512130963 | sahilamundkar2@gmail.com \uf07c LinkedIn | GitHub  \nSUMMARY  \n• AI Engineer with 4 years of experience developing and deploying ML systems across finance, cybersecurity, \nand enterprise AI. \n• Orchestrated AI pipelines integrating conversational AI and customer retention modelling, reducing financial risk \nand improving investment decision workflows by 25% for Fortune 500 clients. \n• Architected Generative AI systems using LangGraph, LangChain, RAG, and LLM fine-tuning, elevating \ndomain-specific response quality by 40% in cybersecurity and compliance auditing use cases. \n• Streamlined data pipelines with Apache Spark, Kafka, Airflow, and AWS, processing over 80M+ transactions \ndaily, automating ingestion, feature engineering, and behavioral drift analysis for model retraining. \n• Operationalized AI models in cloud-native environments using Docker, Kubernetes, AWS SageMaker AI, and \nFastAPI, achieving sub-200ms latency.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='• Operationalized AI models in cloud-native environments using Docker, Kubernetes, AWS SageMaker AI, and \nFastAPI, achieving sub-200ms latency. \n• Systematized workflows with MLflow, GitHub Actions, and CI/CD pipelines, supporting continuous model \nretraining, drift detection, and versioned deployments with 99.5% deployment success rate. \n• Proficient in AI/ML stacks, including PyTorch, TensorFlow, Hugging Face, Scikit-learn, BERT, LLaMA, GPT, \nprompt engineering, and agentic AI systems, in regulated enterprise contexts. \n \nSKILLS \n \nLanguages Python, SQL, JavaScript \nML Frameworks & \nLibraries \nPyTorch, TensorFlow, Keras, Scikit-learn, XGBoost, Random Forest, Hugging Face \nTransformers \nGenerative AI & NLP GPT-4, LLaMA, BERT, QLoRA, LangGraph, LangChain, Retrieval-Augmented \nGeneration, Prompt Engineering, Tokenization, Few-shot Learning, CoT Reasoning, \nVector Databases, Named Entity Recognition (NER), Sentiment Analysis'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Generation, Prompt Engineering, Tokenization, Few-shot Learning, CoT Reasoning, \nVector Databases, Named Entity Recognition (NER), Sentiment Analysis \nMLOps & Deployment MLflow, Docker, Kubernetes, AWS SageMaker, FastAPI, GitHub Actions, CI/CD \npipelines, Canary Deployments, A/B Testing \nData Engineering & Big \nData \nApache Spark, Kafka, Airflow, Feature Engineering, Data Cleaning, Normalization \nCloud Platforms AWS (SageMaker, Lambda, EC2, S3), GCP (VertexAI), Azure (Databricks) \nModel Development Supervised & Unsupervised Learning, LLM Finetuning, Reinforcement Learning \nModel Evaluation SHAP, ROC-AUC, F1 Score, Precision, Recall, Cross-Validation, Statistical Testing, \nBLEU, ROUGE \nData Science  Pandas, NumPy, SciPy, Matplotlib, Seaborn, Plotly \nSoftware Development OOP Principles, Multi-threading, Design Patterns, Agile/Scrum Methodologies, Version \nControl (Git, GitHub) \n \nEDUCATION'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Software Development OOP Principles, Multi-threading, Design Patterns, Agile/Scrum Methodologies, Version \nControl (Git, GitHub) \n \nEDUCATION \n \nMASTER OF SCIENCE in Artificial Intelligence and Robotics, Arizona State University, Tempe, AZ          \nBACHELOR OF ENGINEERING in Electronics Engineering, Mumbai University, India                             \n \nEXPERIENCE \n \nFIDELITY INVESTMENTS | AI ENGINEER, San Francisco, CA                                                            Aug 2024 - Present \n• Built GenAI pipeline automating Chief Investment Office workflows, integrating portfolio optimization, real-time \nmarket intelligence, and compliance monitoring, serving 500+ investment professionals \n• Constructed predictive portfolio allocation models using XGBoost and Scikit-learn, incorporating historical \nreturns, and improving risk-adjusted asset allocation strategies by 12% across live trading.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='returns, and improving risk-adjusted asset allocation strategies by 12% across live trading. \n• Orchestrated data pipelines using Apache Kafka, AWS Glue, and Athena, processing market feeds, financial \nnews, and regulatory updates with 99.8% into structured event streams for downstream GenAI agents. \n• Formulated feature engineering framework for financial signals, generating time-series windows, cross-sector risk \nindicators, supporting both traditional ML models and LLM decision agents.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='• Executed multi-agent orchestration with LangGraph, combining research, compliance, and reporting agents, \nwith semantic routing and task-specific prompt engineering, reducing manual memo creation time by 50%. \n• Optimized large language models (FinGPT, Palmyra) using QLoRA and PEFT (Parameter Efficient Fine-\nTuning), optimizing financial summarization and document classification while reducing GPU memory by 60%. \n• Crafted prompt engineering system with few-shot learning, chain-of-thought prompting, and context \nconstruction for personalized market analysis generation and client-ready investment narratives. \n• Established a RAG (Retrieval-Augmented Generation) pipeline leveraging FAISS and Redis for indexing of \nearnings reports, analyst notes, and regulatory filings, achieving a 35% improvement in retrieval relevance. \n• Launched LLM systems and ML models using AWS SageMaker, and Docker, establishing real-time endpoints'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='• Launched LLM systems and ML models using AWS SageMaker, and Docker, establishing real-time endpoints \nwith CI/CD, reducing deployment cycle time by 30% and ensuring version control. \n• Instituted MLOps and LLMOps infrastructure with MLflow, supporting automated model retraining, continual \nevaluation, drift detection, and reproducible experiment tracking in production environments. \n• Pioneered the development of LLM evaluations, implementing metrics like BLEU, ROUGE, perplexity, and \nfinancial relevance scoring, enabling consistent quality assessment for generative outputs and agent responses. \n \nINTERSOURCES | AI ENGINEER, Mesa, AZ                                                                                     May 2024 - Aug 2024 \n• Engineered a cybersecurity auditing assistant integrating ISO/Soc2/GRC frameworks with company-specific \nevidence, enabling auditors to resolve 60% of compliance queries autonomously via a conversational AI interface.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='evidence, enabling auditors to resolve 60% of compliance queries autonomously via a conversational AI interface. \n• Deployed hybrid ML-LLM architecture, combining XGBoost-based risk scoring and a LLaMA-powered RAG \npipeline, cutting average audit preparation time by 34% and reducing external audit findings by 57%. \n• Constructed data pipelines with Kafka, Airflow, and Spark to ingest logs, IAM exports, vulnerability scans, and \npolicy documents, automating feature generation for both real-time and batch inference workflows. \n• Implemented evaluation framework with retrieval metrics (Precision@k, MRR) and LLM scoring (factual \naccuracy, completeness), lowering incorrect citations by 18% and inference costs by 11%. \n• Instituted FastAPI and SageMaker endpoints for low-latency interaction, enabling auditors to access control risk \nscores, flagged anomalies, and remediation suggestions in real time.'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content="• Instituted FastAPI and SageMaker endpoints for low-latency interaction, enabling auditors to access control risk \nscores, flagged anomalies, and remediation suggestions in real time. \n• Monitored MLflow lifecycle management, versioning models, prompts, and evaluation reports, while integrating \nGrafana-based monitoring to trigger retraining. \n \nCAPGEMINI | AI/ML ENGINEER, Mumbai, India                                                                             May 2020 - Dec 2022 \n• Delivered a fraud detection system using PyTorch and deep neural networks, reducing false positives by 31% \nwhile improving anomaly detection sensitivity in high-volume transactional environments. \n• Calibrated classification models resolving severe class imbalance via SMOTE and financial KPI incorporation, \nboosting recall across 5+ financial institutions' data. \n• Synthesized NLP pipelines with Hugging Face Transformers (BERT) and custom tokenization to extract risk"),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content="boosting recall across 5+ financial institutions' data. \n• Synthesized NLP pipelines with Hugging Face Transformers (BERT) and custom tokenization to extract risk \nentities, intent signals, and customer sentiment from KYC documents, improving monitoring time by 30%. \n• Containerized ML inference services with Docker, and AWS SageMaker Endpoints, achieving a 38% reduction in \nmodel deployment time and enabling A/B testing and canary rollouts in production. \n• Integrated fraud and customer behavior scoring using FastAPI, integrating real-time predictions for both customer \nNPS segmentation (promoter, passive, detractor) and fraud detection with sub-200ms latency on Lambda. \n• Accelerated hyperparameter optimization using Optuna, enhancing model convergence speed and improving F1-\nscore compared to random by 10%, avoiding overfitting legacy patterns. \n• Visualized explainable AI dashboards with Plotly and Seaborn, integrating SHAP values, feature attributions, and"),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-07-21T11:28:41-04:00', 'author': 'Resume Worded', 'moddate': '2026-01-08T15:50:55-05:00', 'source': './files/resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='score compared to random by 10%, avoiding overfitting legacy patterns. \n• Visualized explainable AI dashboards with Plotly and Seaborn, integrating SHAP values, feature attributions, and \nfraud signal analytics, reducing compliance investigation time by 19% and enhancing audit trail transparency. \n• Standardized the ML lifecycle with MLflow and GitHub Actions, for model retraining, data versioning, and drift \ndetection, cutting manual intervention by 25% and ensuring deployments across staging and production. \n• Validated model pipelines using ROC-AUC, cross-validation, and statistical tests with Statsmodels, generating \nregulatory-grade risk scores with high interpretability, meeting strict compliance and audit standards.'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='Job Application for Machine Learning Engineer at GreenhouseBack to jobsMachine Learning EngineerAnywhere in the United StatesApplyOur mission at Greenhouse is to make every company great at hiring – so we go to great lengths to hire great people because we believe that they’re the foundation of our success. At Greenhouse, you’ll join a team that collaborates purposefully, fosters inclusivity, and communicates with transparency and accountability so we can help companies measurably improve the way they hire.\xa0\nJoin us to do the best work of your career, solving meaningful problems with remarkable teams.Greenhouse is looking for a Machine Learning Engineer to join our team!'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content="Join us to do the best work of your career, solving meaningful problems with remarkable teams.Greenhouse is looking for a Machine Learning Engineer to join our team!\nIn this role, you'll work with our team to develop machine learning models that enhance Greenhouse products like resume parsing/anonymization, hiring, sourcing, and predictive analytics. Additionally, we serve to support other product engineering teams on their journey of implementing more machine learning capabilities. You'll collaborate with data science, product, and engineering teams to deploy, monitor, and maintain these models, allowing you to refine your skills and contribute to key projects.\nWho will love this job"),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='A deep learning practitioner – you are eager to unlock the potential of deep learning for various applications\nA generalist – you have experience and the ability to perform a wide variety of software engineering tasks, which are necessary to develop, deploy, and monitor a new software application. You have experience working on whole applications mainly in Python but welcome the opportunity to use Ruby or Typescript as needed\nA collaborator – you are able to work with multiple teams to find the best way to use data to provide value to customers and will do everything needed to make that happen\nAn entrepreneur – someone whose values align with our vision on how A.I. can assist in the hiring process\n\nWhat you’ll do'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='What you’ll do\n\nOwn well-scoped ML components or models: You will take ownership of specific components, executing on defined problems with guidance\nTrain and deploy models using established patterns, and ship models to production following existing tooling and standards\nMonitor and debug models with help from senior engineers, and work to improve model performance incrementally\nImplement AI governance, privacy, and security requirements as defined\nCollaborate within the team and with partner functions, while communicating progress, risks, and blockers clearly\n\nYou should have'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='Degree or recent experience relating to Machine Learning\nFamiliarity with implementing safe, ethical, and compliant ML systems (familiarity with ISO 42001/NIST AI RMF and the associated common controls)\nExperience deploying, monitoring, and improving ML models at a technology company\nA strong grasp of Python\nExperience training and experimenting with deep learning models as well as serving them in production\nExperience with transformers and other HuggingFace libraries\nExperience building and consuming APIs\nAn ability to build consensus while creating space for others\nExcellent prioritization and time management skills\nExperience with NLP and large language models, a plus\nExperience with machine learning models which are not deep learning (e.g. decision trees), a plus\nExperience using Docker and AWS (SageMaker endpoints, SageMaker notebooks, S3, IAM), a plus'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content="Experience with machine learning models which are not deep learning (e.g. decision trees), a plus\nExperience using Docker and AWS (SageMaker endpoints, SageMaker notebooks, S3, IAM), a plus\nYour own unique talents! Your background has given you a unique perspective and set of transferable skills that aren't always in alignment with a given role - but those are qualities we value at Greenhouse. If you don't meet 100% of the qualifications outlined above, we still strongly encourage you to apply"),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content="Applicants must be currently authorized to work in the United States on a full-time basis.\nIf you are based in California, we encourage you to read this important information for California residents linked here.\nThe national pay range for this role is $141,000 - $176,750. Individual compensation will be commensurate with the candidate's experience and qualifications. Certain roles may be eligible for additional compensation, including stock option awards, bonuses, and merit increases. Additionally, certain roles have the opportunity to receive sales commissions that are based on the terms of the sales commission plan applicable to the role."),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='Greenhouse provides a variety of benefits to employees, including medical, dental, and vision insurance, basic life insurance, mental health resources, financial wellness benefits, and a fully paid parental leave program. For US-based employees, we offer short-term and long-term disability coverage, a 401(k) plan and company match. U.S. based employees also receive, per calendar year, up to 14 scheduled paid holidays and up to 80 hours of paid sick leave. Non-exempt employees accrue up to 20-25 days of paid vacation time annually, depending on tenure, and exempt employees have flexible paid time off (PTO).\nThe anticipated closing date for this role is February 20th, 2026\n\xa0Who we are'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='The anticipated closing date for this role is February 20th, 2026\n\xa0Who we are\nAt Greenhouse, we live by our mission through using our own product to help us hire the right person for the job, every time. We are a remote-first company and have shared office spaces in New York City and Ireland, and optional co-working spaces that give us flexibility to do our best work anywhere. We take an active role in our growth through a performance review program that’s committed to providing actionable feedback, and a bonus structure that rewards great performance. We believe that bringing together a variety of perspectives makes us a stronger company – and we nurture leaders who create an inclusive culture and invest into employee resource groups that celebrate our differences and life experiences. We’re proud to have built an award-winning culture that’s been recognized as Fortune’s Best Places to Work and Inc.’s Best Workplaces multiple years in a row.\xa0\n–'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='–\xa0\nGreenhouse Software is an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, sex (including pregnancy, sexual orientation, or gender identity), national origin, age, disability, genetic information, veteran status, or any other characteristic protected by applicable local laws, regulations and ordinances. If you need assistance and/or a reasonable accommodation during the application process, reach out to accommodations@greenhouse.io.'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='Emails about job opportunities at Greenhouse Software are only offered by employees with @greenhouse.io email addresses. See this page on our website if you suspect a phishing scam.Create a Job AlertInterested in building your career at Greenhouse? Get future opportunities sent straight to your email.Create alertApply for this job*indicates a required fieldAutofill with MyGreenhouseFirst Name*Last Name*Email*PhoneCountry*Phone*Location (City)*Locate meResume/CV*AttachAttachDropboxGoogle DriveEnter manuallyEnter manuallyAccepted file types: pdf, doc, docx, txt, rtfCover LetterAttachAttachDropboxGoogle DriveEnter manuallyEnter manuallyAccepted file types: pdf, doc, docx, txt, rtfWhat is your preferred first name? If your legal first name and preferred first name are the same, please input your legal first name.*What is your preferred last name? If your legal last name and preferred last name are the same, please input your legal last name.*In 3-4 sentences, what excites you about this'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content="your legal first name.*What is your preferred last name? If your legal last name and preferred last name are the same, please input your legal last name.*In 3-4 sentences, what excites you about this position at Greenhouse, and how does it align with your long-term career goals?*In 3-4 sentences, please share your experience working with machine learning and deep learning models, including the types of models you've worked with (both deep learning and non-deep learning) and the tools and libraries you've used.*LinkedIn ProfileDue to current team needs, we are only considering candidates based in the USA. Please confirm you're based in the USA."),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='*Select...The national pay range for this role is ($141,000 - $176,750). We prioritize transparency and want to ensure alignment early in the process. Based on this range, do you feel comfortable moving forward with this opportunity? We’re happy to discuss the full compensation package, including benefits, during the interview process.*Select...Are you authorized to work in the United States for any employer?*Select...Will you now or in the future require visa sponsorship?*Select...How did you initially hear about this job?*Select...If you chose Greenhouse Employee, Greenhouse Event, or Other, please specify here:Guidelines for using AI in our interviewing process *Acknowledge/ConfirmAs your prospective employer, Greenhouse has outlined our policy on how candidates are permitted to use AI in our hiring processes. Knowing that the way we experience AI may evolve over time, we will regularly review our approach to AI to ensure alignment with current legislation and to protect against'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='AI in our hiring processes. Knowing that the way we experience AI may evolve over time, we will regularly review our approach to AI to ensure alignment with current legislation and to protect against potential biases in our processes. Prior to engaging in the interview process, please review our current policy.\xa0Are you subject to any non-compete, non-solicitation, or confidentiality agreements with your current or former employers that would impact your employment at Greenhouse?*Select...Demographic questions (US)At Greenhouse, we value belonging and believe in fostering an environment where a diversity of perspectives can thrive. This core value is a pillar of our business and critical to our success. Your responses will be used (in aggregate only) to help us identify\xa0areas of improvement in our process. Your responses\xa0will not\xa0be associated with your specific application and\xa0will not\xa0in any way be used in the hiring decision.I identify my gender as:*Select...I identify as'),
#  Document(metadata={'source': 'https://job-boards.greenhouse.io/greenhouse/jobs/7477093', 'title': 'Job Application for Machine Learning Engineer at Greenhouse', 'language': 'en'}, page_content='improvement in our process. Your responses\xa0will not\xa0be associated with your specific application and\xa0will not\xa0in any way be used in the hiring decision.I identify my gender as:*Select...I identify as transgender:*Select...I identify my sexual orientation as:*Select...I identify my ethnicity as (mark all that apply):*Select...Veteran Status:*Select...I have a physical disability:*Select...This hiring process utilizes artificial intelligence tools to assist in candidate screening and assessment. Our AI tools are designed to complement, not replace, human decision-making.Learn moreSubmit applicationPowered byGreenhouse')]

# %%
# Embedding
embeddings = HuggingFaceEmbeddings(model="all-MiniLM-L6-v2")

# Pinecone

pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

index_name = "jobscore"

# %%
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )
    time.sleep(10)

# %%
vector_store = PineconeVectorStore(index_name=index_name,embedding=embeddings)
uuids = [ str(uuid4()) for _ in range(len(all_docs))]
vector_store.add_documents(documents=all_docs,id=uuids)
# Out:
# ['74b61cb4-9bef-426e-ab54-d9916950f363',
#  '2593aa81-0816-44f6-9e21-6b8c063d49c8',
#  'b0d4ae97-b78c-4003-bd0c-2f51e63daa7d']

# %%
# retriver
retriver = vector_store.as_retriever(search_type ="mmr",search_kwargs={"k":3,"fetch_keys":4})

# format_docs
def format_docs(all_docs):
    return "\n\n".join([d.page_content for d in all_docs])

# Prompt
template = """
Answer the qeustion based on context.
Context: {context}
Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# model
model = ChatGroq(model ="qwen/qwen3-32b")

# %%
# Chain

chain = (
    {"context": retriver | format_docs , "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
query = """
Compare the Job Description requirements against the Candidate's Resume. 
Identify the key technical skills match, and explicitly list the missing skills or experience gaps.
"""

print(f"result {query}")
# Out:
# result
# Compare the Job Description requirements against the Candidate's Resume.
# Identify the key technical skills match, and explicitly list the missing skills or experience gaps.

# %%
start = time.time()
response = chain.invoke(query)
end = time.time()

# Save to Word
doc = Document()
doc.add_heading('Assignment Report', 0)
doc.add_paragraph(f"Query: {query}")
doc.add_paragraph(f"Answer: {response}")
doc.add_paragraph(f"Time Taken: {end - start:.2f} seconds")
doc.save('Simple_Report.docx')
